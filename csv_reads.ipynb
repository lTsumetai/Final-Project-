# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("artifacts/topics_negative.csv")
df.sample(10)
# Out:
#     Topic  Count                                     Name  \
# 3       2    210            2_packing_box_rapi_packingnya
# 14     13     96               13_pcs_beli_video_komplain
# 9       8    209           8_pengiriman_tanggal_lama_hari
# 15     14     85                   14_jam_lama_pakai_baru
# 17     16     77  16_mic_suara_berfungsi_enggak berfungsi
# 5       4    161            4_nyala_lampu_berfungsi_kabel
# 16     15    103          15_jelek_kuat_jelek jelek_tipis
# 12     11     65           11_buku_bukunya_halaman_kertas
# 6       5    119             5_enak_bau_enggak enak_wangi
# 8       7     79         7_bubble_bubble wrap_wrap_kardus
#
#                                        Representation  \
# 3   ['packing', 'box', 'rapi', 'packingnya', 'plas...
# 14  ['pcs', 'beli', 'video', 'komplain', 'coba', '...
# 9   ['pengiriman', 'tanggal', 'lama', 'hari', 'pro...
# 15  ['jam', 'lama', 'pakai', 'baru', 'hari', 'baru...
# ...

# %%
df = pd.read_csv("artifacts/topics_positive.csv")
df.sample(10)
# Out:
#     Topic  Count                                               Name  \
# 2       1    308         1_pengiriman_pengiriman cepat_cepat_barang
# 0      -1      2                                             -1____
# 5       4    178     4_packaging_packaging aman_aman_packaging rapi
# 13     12     87             12_sesuai pesanan_order_pesanan_repeat
# 12     11     79           11_mantap_mantap mantap_kinclong_menjadi
# 6       5    212                 5_terima_terima kasih_kasih_barang
# 3       2    273                    2_bagus_mantap_barang_berfungsi
# 14     13     95                13_kasih_seller_terima_terima kasih
# 8       7    125  7_produk_produk bagus_produk sesuai_produk ori...
# 16     15    115                      15_enggak_berfungsi_buat_cuma
#
#                                        Representation  \
# 2   ['pengiriman', 'pengiriman cepat', 'cepat', 'b...
# 0            ['', '', '', '', '', '', '', '', '', '']
# ...

# %%
pd.read_csv("artifacts/themes_negative.csv")
# Out:
#                        theme  reviews   pct
# 0      Item not as described      643  22.8
# 1      Poor quality / flimsy      449  15.9
# 2        Unresponsive seller      412  14.6
# 3  Defective / does not work      323  11.4
# 4          Damaged packaging      289  10.2
# 5     General disappointment      228   8.1
# 6              Slow delivery      209   7.4
# 7      Broken / damaged item      148   5.2
# 8         Bad smell or taste      119   4.2
# 9                      Other        1   0.0

# %%
pd.read_csv("artifacts/themes_positive.csv")
# Out:
#                               theme  reviews   pct
# 0  Good / works / authentic product      557  21.6
# 1             Safe & neat packaging      417  16.2
# 2           Thanks & general praise      386  15.0
# 3       Responsive, friendly seller      374  14.5
# 4                     Fast delivery      308  11.9
# 5                Material & comfort      283  11.0
# 6           Affordable / good value      165   6.4
# 7         Repeat order / as ordered       87   3.4
# 8                             Other        2   0.1

# %%
df = pd.read_csv("artifacts/reviews_with_themes.csv")


examples_df = df.groupby("Emotion").head(1)


examples_df
# Out:
#                    Category  \
# 0     Computers and Laptops
# 40    Computers and Laptops
# 2579  Computers and Laptops
# 2619  Computers and Laptops
# 2659  Computers and Laptops
#
#                                            Product Name Sentiment  Emotion  \
# 0     Wireless Keyboard i8 Mini TouchPad Mouse 2.4G ...  Positive    Happy
# 40    [FS] Logitech MK275 Wireless Keyboard Mouse Combo  Positive     Love
# 2579  Logitech M191 Mouse Wireless Full Size - Mid Grey  Negative  Sadness
# 2619  Charger Adaptor MacBook Pro 2008 2009 2010 201...  Negative    Anger
# 2659  Laptop Stand Holder Lipat Adjustable Anti Slip...  Negative     Fear
#
#                                         Customer Review  topic  \
# 0     Alhamdulillah berfungsi dengan baik. Packaging...      4
# 40    Bagus banget keyboardnya. Packing sangat aman ...     15
# 2579    Sangat kecewa. Baru 4 bulan scroll sudah rusak.     10
# 2619  Sangat mengecewakan, barang yg dikirim tidak s...     18
# ...
